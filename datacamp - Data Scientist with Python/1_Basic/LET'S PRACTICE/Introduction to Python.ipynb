# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Which one of these will return 5 ?

# %%
bool(1) * int(4.2) + 1
# Out:
# 5

# %% [markdown]
# numpy1 = np.array([17.2, 20.0, 8.25, 9.50])
# numpy2 = np.array([13.0, 24.0, 8.25, 9.0])
# np.logicl_and(numpy1 > 10, numpy2 < 20)
# array([ True, False, False, False], dtype=bool)

# %%
numpy1 = np.array([17.2, 20.0, 8.25, 9.50])
numpy2 = np.array([13.0, 24.0, 8.25, 9.0])
np.logical_and(numpy1 > 10, numpy2 < 20)
# Out:
# array([ True, False, False, False])

# %% [markdown]
# ![image.png](attachment:image.png)
#
# plt.scatter([1,2,3,4],[5,6,7,8])

# %%
plt.scatter([1,2,3,4],[5,6,7,8])

# %%
np.arange(3)
# Out:
# array([0, 1, 2])

# %%
array_2D = np.array([[ 5,  1,  3,  2,  4,  6],
       [ 5,  8,  0,  3,  1,  2],
       [ 3, 10,  6, 21, 15,  1]])

np.sort(array_2D,axis=0)
# Out:
# array([[ 3,  1,  0,  2,  1,  1],
#        [ 5,  8,  3,  3,  4,  2],
#        [ 5, 10,  6, 21, 15,  6]])

# %%
np.zeros((2, 4))
# Out:
# array([[0., 0., 0., 0.],
#        [0., 0., 0., 0.]])
