# %% [markdown]
# """ The code you've written up to now is available in the script.
#
# The next step is making the plot more colorful! To do this, a list col has been created for you. It's a list with a color for each corresponding country, depending on the continent the country is part of.
#
# How did we make the list col you ask? The Gapminder data contains a list continent with the continent each country belongs to. A dictionary is constructed that maps continents onto colors: """
# dict = {
#     'Asia':'red',
#     'Europe':'green',
#     'Africa':'blue',
#     'Americas':'yellow',
#     'Oceania':'black'
# }
#
# """ Nothing to worry about now; you will learn about dictionaries in the next chapter. """
#
# """ Add c = col to the arguments of the plt.scatter() function.
# Change the opacity of the bubbles by setting the alpha argument to 0.8 inside plt.scatter(). Alpha can be set from zero to one, where zero is totally transparent, and one is not at all transparent. """

# %%
import pandas as pd
import matplotlib.pyplot as plt
path=r'/media/documentos/Cursos/Data Science/Python/Data_Science_Python/data_sets/'

gapminder=pd.read_csv(path+'gapminder.csv')
print('gapminder \n',gapminder.head(),'\n')

life_exp=gapminder['life_exp'].values.tolist()
print('life_exp \n',life_exp[0:10],'\n')

gdp_cap= gapminder['gdp_cap'].values.tolist()
print('gdp_cap \n',gdp_cap[0:10],'\n')

pop= gapminder['population'].values.tolist()
print('population \n',pop[0:10],'\n')

dict = { 'cont':['Asia','Europe','Africa','Americas','Oceania'],
         'color':['red','green','blue','yellow','black']
        }

colors=pd.DataFrame.from_dict(dict)
#colors.columns=['cont','color']
print('colors \n',colors,'\n')

coun_col=pd.merge(gapminder,colors,on='cont')

col=coun_col['color'].values.tolist()

print('coun_col \n',col[0:20],'\n')
# Out:
# gapminder
#     Unnamed: 0      country  year  population      cont  life_exp       gdp_cap
# 0          11  Afghanistan  2007  31889923.0      Asia    43.828    974.580338
# 1          23      Albania  2007   3600523.0    Europe    76.423   5937.029526
# 2          35      Algeria  2007  33333216.0    Africa    72.301   6223.367465
# 3          47       Angola  2007  12420476.0    Africa    42.731   4797.231267
# 4          59    Argentina  2007  40301927.0  Americas    75.320  12779.379640
#
# life_exp
#  [43.828, 76.423, 72.301, 42.731, 75.32, 81.235, 79.829, 75.635, 64.062, 79.441]
#
# gdp_cap
#  [974.5803384, 5937.029526, 6223.367465, 4797.231267, 12779.37964, 34435.36744, 36126.4927, 29796.04834, 1391.253792, 33692.60508]
#
# population
#  [31889923.0, 3600523.0, 33333216.0, 12420476.0, 40301927.0, 20434176.0, 8199783.0, 708573.0, 150448339.0, 10392226.0]
#
# colors
#         cont   color
# 0      Asia     red
# 1    Europe   green
# 2    Africa    blue
# 3  Americas  yellow
# ...

# %%
import numpy as np

# Specify c and alpha inside plt.scatter()
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop)/1000000,c = col,alpha=0.8 )

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Show the plot
plt.show()

# %%
pd.__version__
# Out:
# '1.5.0'
