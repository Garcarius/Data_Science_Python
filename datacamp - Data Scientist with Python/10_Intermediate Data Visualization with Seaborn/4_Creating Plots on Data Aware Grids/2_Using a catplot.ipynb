# %% [markdown]
# # Using a catplot
# In many cases, Seaborn's `catplot()` can be a simpler way to create a `FacetGrid`. Instead of creating a grid and mapping the plot, we can use the `catplot()` to create a plot with one line of code.
#
# For this exercise, we will recreate one of the plots from the previous exercise using `catplot()` and show how to create a `boxplot` on a data-aware grid.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file=r"D:\Cursos\Data_Science_Python\data_sets\college_datav3.csv"
df= pd.read_csv(file)
df.head(3)
# Out:
#                                 INSTNM    OPEID  REGION  SAT_AVG_ALL  PCTPELL  \
# 0             Alabama A & M University   100200       5        850.0   0.7249
# 1  University of Alabama at Birmingham   105200       5       1147.0   0.3505
# 2                   Amridge University  2503400       5          NaN   0.7455
#
#    PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL COMPL_RPY_5YR_RT  ... CONTROL  \
# 0    0.8159      0.653841   4380.0     7017.0      0.477631579  ...       1
# 1    0.5218      0.604275  10331.0    10221.0      0.673230442  ...       1
# 2    0.8781           NaN     98.0     3217.0      0.636363636  ...       2
#
#   WOMENONLY  MENONLY  LOCALE  Tuition  Degree_Type           Ownership  \
# 0       0.0      0.0    12.0  13435.0     Graduate              Public
# 1       0.0      0.0    12.0  16023.0     Graduate              Public
# 2       0.0      0.0    12.0   8862.0     Graduate  Private non-profit
#
#       Regions        Locales Locale_Short
# 0  South East  City: Midsize         City
# 1  South East  City: Midsize         City
# 2  South East  City: Midsize         City
#
# [3 rows x 24 columns]

# %% [markdown]
# * Create a `catplot()` that contains a boxplot (`box`) of `Tuition` values varying by `Degree_Type` across rows.

# %%
# Create a factor plot that contains boxplots of Tuition values
sns.catplot(data=df,
         x='Tuition',
         kind='box',
         row='Degree_Type')

plt.show()
plt.clf()

# %% [markdown]
# * Create a `catplot()` of SAT Averages (`SAT_AVG_ALL`) facetted across `Degree_Type` that shows a pointplot (`point`).
# * Use `row_order` to order the degrees from highest to lowest level.

# %%
# Create a facetted pointplot of Average SAT_AVG_ALL scores facetted by Degree Type 
sns.catplot(data=df,
        x='SAT_AVG_ALL',
        kind='point',
        row='Degree_Type',
        row_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])

plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Garca\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3016, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3015 try:
# -> 3016     plot_func = globals()[kind + "plot"]
#    3017 except KeyError:
#
# KeyError: 'pointplotplot'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Create a facetted pointplot of Average SAT_AVG_ALL scores facetted by Degree Type
# ----> 2 sns.catplot(data=df,
#       3         x='SAT_AVG_ALL',
#       4         kind='pointplot',
#       5         row='Degree_Type',
#       6         row_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])
#       8 plt.show()
#       9 plt.clf()
#
# File c:\Users\Garca\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3019, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3017 except KeyError:
#    3018     err = f"Plot kind '{kind}' is not recognized"
# -> 3019     raise ValueError(err)
#    3021 # Check for attempt to plot onto specific axes and warn
#    3022 if "ax" in kwargs:
#
# ValueError: Plot kind 'pointplot' is not recognized
