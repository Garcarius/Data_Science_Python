# %% [markdown]
# # Accessing and filtering data
# You are working on a Python application to display information about the dogs available for adoption at your local animal shelter. Some of the variables of interest, such as "breed", `"size"`, and `"coat"`, are saved as categorical variables. In order for this application to work properly, you need to be able to access and filter data using these columns.
#
# The `ID` variable has been set as the index of the `pandas` DataFrame `dogs`.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file='ShelterDogs.csv'
path=r"D:\\Cursos\\Data_Science_Python\\data_sets\\"
pathfile=path+file
try:
 df= pd.read_csv(pathfile)
 print(df.head(5))
except :
  print('file doesnt exist')

dogs = df[:]
# Out:
#       ID            name   age     sex               breed date_found  \
# 0  23807            Gida  0.25  female         Unknown Mix   12/10/19
# 1    533  Frida És Ricsi  0.17  female         Unknown Mix    12/1/19
# 2  23793             NaN  4.00    male         Unknown Mix    12/8/19
# 3  23795             NaN  1.00    male         Unknown Mix    12/8/19
# 4  23806             Amy  2.00  female  French Bulldog Mix   12/10/19
#
#   adoptable_from    posted            color    coat    size neutered  \
# 0       12/11/19  12/11/19              red   short   small       no
# 1        12/1/19   12/9/19  black and white   short   small       no
# 2       12/23/19   12/8/19      saddle back   short  medium       no
# 3       12/23/19   12/8/19     yellow-brown  medium  medium       no
# 4       12/11/19  12/11/19            black   short   small       no
#
#   housebroken likes_people likes_children get_along_males get_along_females  \
# 0         NaN          NaN            NaN             NaN               NaN
# 1         NaN          yes            yes             yes               yes
# 2         NaN          NaN            NaN             NaN               NaN
# 3         NaN          NaN            NaN             NaN               NaN
# 4         NaN          NaN            NaN             NaN               NaN
#
#   get_along_cats keep_in
# 0            NaN     NaN
# 1            yes     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN

# %% [markdown]
# * Print the `"coat"` value for the dog with an `ID` of 23807.

# %%
# Print the category of the coat for ID 23807
print(dogs.loc[dogs['ID']==23807, "coat"])
# Out:
# 0    short
# Name: coat, dtype: object

# %%
dogs.set_index('ID')
# Out:
#                  name    age     sex                           breed  \
# ID
# 23807            Gida   0.25  female                     Unknown Mix
# 533    Frida És Ricsi   0.17  female                     Unknown Mix
# 23793             NaN   4.00    male                     Unknown Mix
# 23795             NaN   1.00    male                     Unknown Mix
# 23806             Amy   2.00  female              French Bulldog Mix
# ...               ...    ...     ...                             ...
# 118             Fodri  16.92    male                     Unknown Mix
# 262             Csibi  17.33  female       Staffordshire Terrier Mix
# 4              Konrád  18.17    male                     Unknown Mix
# 141             Kölni  17.17    male                     Unknown Mix
# 248            Kedves  16.08    male  German Shepherd Dog, Hound Mix
#
#       date_found adoptable_from    posted            color    coat    size  \
# ID
# 23807   12/10/19       12/11/19  12/11/19              red   short   small
# 533      12/1/19        12/1/19   12/9/19  black and white   short   small
# 23793    12/8/19       12/23/19   12/8/19      saddle back   short  medium
# 23795    12/8/19       12/23/19   12/8/19     yellow-brown  medium  medium
# 23806   12/10/19       12/11/19  12/11/19            black   short   small
# ...          ...            ...       ...              ...     ...     ...
# 118     12/25/03       12/25/03   3/22/06     yellow-brown   short  medium
# 262      8/27/04        8/27/04    7/8/05          striped   short   large
# 4        9/21/05        9/21/05  10/26/05            black   short  medium
# 141     11/27/04       11/27/04    5/2/05  black and brown  medium  medium
# 248       4/2/05         4/2/05   6/30/05            sable   short  medium
#
#       neutered housebroken likes_people likes_children get_along_males  \
# ID
# 23807       no         NaN          NaN            NaN             NaN
# 533         no         NaN          yes            yes             yes
# 23793       no         NaN          NaN            NaN             NaN
# 23795       no         NaN          NaN            NaN             NaN
# 23806       no         NaN          NaN            NaN             NaN
# ...        ...         ...          ...            ...             ...
# 118         no          no          yes            yes              no
# 262        yes         NaN          NaN            NaN             NaN
# 4           no         NaN          NaN            NaN             NaN
# 141         no         NaN          NaN            NaN             NaN
# 248        yes         NaN          yes            NaN             yes
#
#       get_along_females get_along_cats               keep_in
# ID
# 23807               NaN            NaN                   NaN
# 533                 yes            yes                   NaN
# 23793               NaN            NaN                   NaN
# 23795               NaN            NaN                   NaN
# 23806               NaN            NaN                   NaN
# ...                 ...            ...                   ...
# 118                 yes             no                garden
# 262                 NaN            NaN                   NaN
# 4                   NaN            NaN                   NaN
# 141                 NaN            NaN                   NaN
# 248                 yes            NaN  both flat and garden
#
# [2937 rows x 18 columns]

# %%
# Print the category of the coat for ID 23807
print(dogs.loc[dogs['ID']==23807, "coat"])
# Out:
# 0    short
# Name: coat, dtype: object

# %% [markdown]
# For dogs with a long "coat", print the number of each "sex"

# %%
# Find the count of male and female dogs who have a "long" coat
print(dogs.loc[dogs['coat']=="long", 'sex'].value_counts())
# Out:
# male      124
# female     56
# Name: sex, dtype: int64

# %% [markdown]
# * Print the average age of dogs with a `"breed"` of "English Cocker Spaniel".

# %%
# Print the mean age of dogs with a breed of "English Cocker Spaniel"
print(dogs.loc[dogs['breed']=="English Cocker Spaniel", 'age'].mean())
# Out:
# 8.186153846153847

# %% [markdown]
# Filter to the dogs with "English" in their `"breed"` name using the .contains() method.

# %%
# Count the number of dogs that have "English" in their breed name
print(dogs[dogs["breed"].str.contains('English', regex=False)].shape[0])
# Out:
# 35
